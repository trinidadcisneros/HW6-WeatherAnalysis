# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['rikitea',
#  'punta arenas',
#  'yellowknife',
#  'bredasdorp',
#  'tasiilaq',
#  'busselton',
#  'hobart',
#  'waddan',
#  'nikolskoye',
#  'whyalla',
#  'bluff',
#  'babanusah',
#  'sandakan',
#  'nome',
#  'yarada',
#  'airai',
#  'tuktoyaktuk',
#  'mount isa',
#  'namibe',
#  'mahebourg',
#  'elmvale',
#  'port lincoln',
#  'sola',
#  'saldanha',
#  'mataura',
#  'sistranda',
#  'damietta',
#  'mangrol',
#  'boa vista',
#  'kendari',
#  'marzuq',
#  'chokurdakh',
#  'kirakira',
#  'atuona',
#  'jamestown',
#  'saint-philippe',
#  'carnarvon',
#  'east london',
#  'muyezerskiy',
#  'souillac',
#  'gat',
#  'nizhneyansk',
#  'ushuaia',
#  'isangel',
#  'narsaq',
#  'vangaindrano',
#  'qaanaaq',
#  'sorvag',
#  'klaksvik',
#  'karakendzha',
#  'pisco',
#  'attawapiskat',
#  'new norfolk',
#  'batagay',
#  'conde',
#  'hermanus',
#  'eshowe',
#  'albany',
#  'tuatapere',
#  'arlit',
#  'la ronge',
#  'puerto ayora',
#  'honiara',
#  'dubbo',
#  'cape town',
#  'tanout',
#  'machacamarca',
#  'tiksi',
#  'hayden',
#  'yulara',
#  'ambon',
#  'provideniya',
#  'talcahuano',
#  'cherskiy',
#  'kruisfontein',
#  'illoqqortoormiut',
#  'khatanga',
#  'barrow',
#  'puerto lempira',
#  'cidreira',
#  'margate',
#  'hithadhoo',
#  'virginia beach',
#  'kapaa',
#  'ribeira grande',
#  'solwezi',
#  'warqla',
#  'hilo',
#  'kodiak',
#  'tungkang',
#  'deputatskiy',
#  'atambua',
#  'adrar',
#  'kaitangata',
#  'dunda',
#  'meulaboh',
#  'namatanai',
#  'tagusao',
#  'mar del plata',
#  'ariquemes',
#  'kaduqli',
#  'sentyabrskiy',
#  'gornyy',
#  'praia',
#  'coihaique',
#  'roebourne',
#  'lagoa',
#  'las cruces',
#  'samusu',
#  'zvishavane',
#  'aqtobe',
#  'alice springs',
#  'rabo de peixe',
#  'ballina',
#  'bitung',
#  'yumen',
#  'burica',
#  'pokrovsk',
#  'butaritari',
#  'ganzhou',
#  'kasongo-lunda',
#  'jiangyou',
#  'ukholovo',
#  'tessalit',
#  'tautira',
#  'norman wells',
#  'bengkulu',
#  'kutum',
#  'ilam',
#  'pevek',
#  'chuy',
#  'kallifitos',
#  'vila franca do campo',
#  'hamilton',
#  'victoria',
#  'uniontown',
#  'khapa',
#  'lima',
#  'ancud',
#  'ponta do sol',
#  'bethel',
#  'san patricio',
#  'port alfred',
#  'torbay',
#  'aden',
#  'bam',
#  'hofn',
#  'alanya',
#  'nouadhibou',
#  'perth',
#  'longyearbyen',
#  'ojinaga',
#  'avarua',
#  'pangody',
#  'tabiauea',
#  'labutta',
#  'lorengau',
#  'moroto',
#  'luderitz',
#  'northam',
#  'takoradi',
#  'gamba',
#  'labuhan',
#  'dikson',
#  'laguna',
#  'vila velha',
#  'saint-donat-de-montcalm',
#  'saint anthony',
#  'brigg',
#  'mackenzie',
#  'port blair',
#  'rio grande',
#  'abdulino',
#  'liepaja',
#  'horsham',
#  'tambilil',
#  'bongandanga',
#  'yar-sale',
#  'hami',
#  'vaini',
#  'lakhdenpokhya',
#  'ilulissat',
#  'santa catalina',
#  'karratha',
#  'castro',
#  'brigantine',
#  'atagay',
#  'mys shmidta',
#  'greeley',
#  'guerrero negro',
#  'bambous virieux',
#  'najran',
#  'san rafael',
#  'port elizabeth',
#  'broken hill',
#  'suntar',
#  'cabanas',
#  'bahia honda',
#  'geraldton',
#  'thompson',
#  'iqaluit',
#  'brokopondo',
#  'tulle',
#  'amderma',
#  'bathsheba',
#  'usinsk',
#  'banamba',
#  'xuddur',
#  'marawi',
#  'belushya guba',
#  'pangnirtung',
#  'hihifo',
#  'inongo',
#  'ust-kan',
#  'togur',
#  'fallon',
#  'kavaratti',
#  'naze',
#  'san juan',
#  'kreminna',
#  'porterville',
#  'richards bay',
#  'belyy yar',
#  'mecca',
#  'vaitupu',
#  'lufilufi',
#  'sungaipenuh',
#  'san cristobal',
#  'yatou',
#  'taolanaro',
#  'taltal',
#  'chama',
#  'ippy',
#  'barahona',
#  'roald',
#  'palpa',
#  'chara',
#  'oriximina',
#  'boquira',
#  'dzhebariki-khaya',
#  'usila',
#  'biloela',
#  'lebu',
#  'gigmoto',
#  'kargopol',
#  'crab hill',
#  'kahului',
#  'half moon bay',
#  'baherden',
#  'tura',
#  'yamada',
#  'zhigansk',
#  'abalak',
#  'arraial do cabo',
#  'nanortalik',
#  'jumla',
#  'sao joao da barra',
#  'porto novo',
#  'tateyama',
#  'stulovo',
#  'tsihombe',
#  'srednekolymsk',
#  'aklavik',
#  'weyburn',
#  'iberia',
#  'jining',
#  'anloga',
#  'georgetown',
#  'faanui',
#  'carrickmacross',
#  'palabuhanratu',
#  'bonavista',
#  'mocuba',
#  'henderson',
#  'miquelon',
#  'muros',
#  'umzimvubu',
#  'beidao',
#  'sibolga',
#  'barentsburg',
#  'guilin',
#  'fukue',
#  'san quintin',
#  'bowen',
#  'sai buri',
#  'luang prabang',
#  'shiyan',
#  'hualmay',
#  'lolua',
#  'marsa matruh',
#  'sao jose da coroa grande',
#  'jacareacanga',
#  'nelson bay',
#  'bauchi',
#  'westport',
#  'komsomolskiy',
#  'saskylakh',
#  'san policarpo',
#  'yuzhno-yeniseyskiy',
#  'fortuna',
#  'nantucket',
#  'shingu',
#  'bolshegrivskoye',
#  'clyde river',
#  'pacific grove',
#  'riyadh',
#  'constitucion',
#  'obo',
#  'yantzaza',
#  'hobyo',
#  'severo-kurilsk',
#  'beipiao',
#  'dawlatabad',
#  'cairns',
#  'tenenkou',
#  'rudnya',
#  'pointe-noire',
#  'santa rosa',
#  'izumo',
#  'yichang',
#  'saint-pierre',
#  'merauke',
#  'gouyave',
#  'saint-georges',
#  'schaffhausen',
#  'panaba',
#  'altamira',
#  'bac lieu',
#  'peleduy',
#  'aljezur',
#  'juneau',
#  'sabha',
#  'dingle',
#  'ust-kuyga',
#  'grindavik',
#  'nouakchott',
#  'prince george',
#  'grand gaube',
#  'mayya',
#  'saint-ambroise',
#  'mitha tiwana',
#  'sao gabriel da cachoeira',
#  'petropavlovsk-kamchatskiy',
#  'zaporizhzhya',
#  'jinchang',
#  'saleaula',
#  'ovsyanka',
#  'shimoda',
#  'iroquois falls',
#  'hohhot',
#  'beringovskiy',
#  'vaitape',
#  'yining',
#  'port hardy',
#  'cuamba',
#  'berdigestyakh',
#  'uglekamensk',
#  'chernyshevskiy',
#  'polovinnoye',
#  'prince rupert',
#  'kamenskoye',
#  'roanoke rapids',
#  'katsuura',
#  'esperance',
#  'kirovskiy',
#  'malakal',
#  'saint george',
#  'tefe',
#  'leningradskiy',
#  'padang',
#  'gorontalo',
#  'zhuanghe',
#  'aberdeen',
#  'camacha',
#  'thomaston',
#  'verkhnevilyuysk',
#  'nichinan',
#  'santa isabel do rio negro',
#  'banda aceh',
#  'nacala',
#  'altay',
#  'sao filipe',
#  'sitka',
#  'westpunt',
#  'deniliquin',
#  'jiwani',
#  'awjilah',
#  'bad salzungen',
#  'yaan',
#  'cabrobo',
#  'jabiru',
#  'fairbanks',
#  'haguenau',
#  'skeldon',
#  'nishihara',
#  'placer',
#  'elliot',
#  'rongcheng',
#  'corner brook',
#  'upernavik',
#  'aykhal',
#  'nuevitas',
#  'torrelavega',
#  'lano',
#  'plettenberg bay',
#  'lakes entrance',
#  'kawana waters',
#  'nyazepetrovsk',
#  'yingzhong',
#  'qasigiannguit',
#  'sulangan',
#  'olafsvik',
#  'abu dhabi',
#  'meiganga',
#  'kununurra',
#  'turukhansk',
#  'chipinge',
#  'russell',
#  'grand river south east',
#  'hurghada',
#  'katakwi',
#  'zemio',
#  'nova odesa',
#  'kailua',
#  'parfenyevo',
#  'krasnoselkup',
#  'celestun',
#  'tachov',
#  'nalut',
#  'agadir',
#  'heiligenhafen',
#  'lavrentiya',
#  'mokobeng',
#  'cururupu',
#  'bone',
#  'bougouni',
#  'vazante',
#  'seoul',
#  'khotyn',
#  'mendahara',
#  'bo',
#  'kushima',
#  'jamame',
#  'luban',
#  'saint-augustin',
#  'chandur',
#  'porto walter',
#  'opuwo',
#  'atar',
#  'kavieng',
#  'ercis',
#  'custoias',
#  'kalanwali',
#  'sept-iles',
#  'avera',
#  'hambantota',
#  'bolgatanga',
#  'atbasar',
#  'hay river',
#  'san martin',
#  'alexandria',
#  'barawe',
#  'sorong',
#  'codrington',
#  'kishtwar',
#  'antsla',
#  'laibin',
#  'acapulco',
#  'dromolaxia',
#  'nanyuki',
#  'igarka',
#  'arman',
#  'kichmengskiy gorodok',
#  'melo',
#  'moyale',
#  'misratah',
#  'manoharpur',
#  'aginskoye',
#  'trenggalek',
#  'qui nhon',
#  'samarai',
#  'livingston',
#  'husavik',
#  'champerico',
#  'killin',
#  'teya',
#  'sompeta',
#  'umm lajj',
#  'madang',
#  'pemba',
#  'dongsheng',
#  'inuvik',
#  'bandar',
#  'tskaltubo',
#  'lodja',
#  'schwandorf',
#  'svetlogorsk',
#  'gorin',
#  'rocha',
#  'mumford',
#  'oksfjord',
#  'bubaque',
#  'miranorte',
#  'anadyr',
#  'port shepstone',
#  'montorio al vomano',
#  'pekan',
#  'gobabis',
#  'meyungs',
#  'ormond beach',
#  'loandjili',
#  'nabire',
#  'shashi',
#  'nuevo casas grandes',
#  'purulha',
#  'ambunti',
#  'mandalgovi',
#  'basar',
#  'marsh harbour',
#  'faya',
#  'lompoc',
#  'shahr-e babak',
#  'uspenka',
#  'kloulklubed',
#  'dunedin',
#  'aquiraz',
#  'puerto narino',
#  'sabibah',
#  'ouallam',
#  'minab',
#  'copperas cove',
#  'shirgaon',
#  'vardo',
#  'taburi',
#  'hedaru',
#  'synya',
#  'harper',
#  'shimizu',
#  'shelton',
#  'malatya',
#  'wewak',
#  'otane',
#  'bur gabo',
#  'mareeba',
#  'gushikawa',
#  'talnakh',
#  'guymon',
#  'jalu',
#  'eirunepe',
#  'waipawa',
#  'yenotayevka',
#  'caravelas',
#  'gladstone',
#  'almunecar',
#  'hasaki',
#  'oussouye',
#  'crotone',
#  'belmonte',
#  'urusha',
#  'halifax',
#  'louisbourg',
#  'willowmore',
#  'rawlins',
#  'bichura',
#  'maceio',
#  'la orilla',
#  'rock springs',
#  'dum duma',
#  'cabo san lucas',
#  'mabaruma',
#  'soluno-dmitriyevskoye',
#  'hit',
#  'mechanicsville',
#  'diffa',
#  'ahuimanu',
#  'benjamin aceval',
#  'kemijarvi',
#  'el wasta',
#  'sexsmith',
#  'mahibadhoo',
#  'pontianak',
#  'achisay',
#  'asau',
#  'dzhusaly',
#  'buarcos',
#  'xichang',
#  'veraval',
#  'lazaro cardenas',
#  'guiyang',
#  'novyy urengoy',
#  'san carlos de bariloche',
#  'libertador general san martin',
#  'daru',
#  'yirol',
#  'ust-kamchatsk',
#  'broome',
#  'sao goncalo do amarante',
#  'buin',
#  'silyanah',
#  'fort smith',
#  'coleraine',
#  'avdiyivka',
#  'aksarka',
#  'poanas',
#  'vysokogornyy',
#  'puerto baquerizo moreno',
#  'toamasina',
#  'yulin',
#  'aswan',
#  'kourou',
#  'jizan',
#  'minatitlan',
#  'manicore',
#  'vila do maio',
#  'denpasar',
#  'marcona',
#  'ouango',
#  'port hawkesbury',
#  'karakol',
#  'tokmak',
#  'sangar',
#  'jales',
#  'levokumskoye',
#  'mehamn',
#  'pochutla',
#  'chunskiy',
#  'changli',
#  'les cayes',
#  'kuytun',
#  'grand-santi',
#  'san miguel',
#  'hwange',
#  'tigil',
#  'henties bay']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "castro"

query_url = f"{url}appid={api_key}&q={city}"
weather_response = requests.get(query_url)
weather_json = weather_response.json()
date = weather_json['dt']
date
# Out:
# 1550538000

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Next, spend the requisite time necessary to study the OpenWeatherMap API. 
# Based on your initial study, you should be able to answer basic questions about the API: 
# Where do you request the API key? 
# Which Weather API in particular will you need? 
# api.openweathermap.org/data/2.5/weather?q={city name}
# api.openweathermap.org/data/2.5/weather?q={nizhneyansk}
# What URL endpoints does it expect? 
# What JSON structure does it respond with? 
# Before you write a line of code, 
# you should be aiming to have a crystal clear understanding of your intended outcome.

url = "http://api.openweathermap.org/data/2.5/weather?"
city_data = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Get weather data
print("Beginning Data Retrieval")
print("------------------------------")

index = 1
for city in cities:
    query_url = f"{url}appid={api_key}&q={city}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    try:
        lat.append(weather_json["coord"]["lat"])      
    except: pass
    try:
        lng.append(weather_json["coord"]["lon"])
    except: pass
    try:
        humidity.append(weather_json["main"]["humidity"])
    except: pass
    try:
        max_temp.append(weather_json["main"]["temp_max"])
    except: pass
    try:
        wind_speed.append(weather_json["wind"]["speed"])
    except: pass
    try:
        cloudiness.append(weather_json["clouds"]["all"])
    except: pass
    try:
        country.append(weather_json["sys"]["country"])
    except: pass        
    try:
        date.append(weather_json['dt'])
    except: pass
    try:
        city_data.append(weather_json["name"])
        print(f"Processing Record {index} of Set {index} | {city}") 
    except (NameError, KeyError):
        print("Not found. Skipping...")    
    index = index + 1
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 5 | tasiilaq
# Processing Record 6 of Set 6 | busselton
# Processing Record 7 of Set 7 | hobart
# Processing Record 8 of Set 8 | waddan
# Processing Record 9 of Set 9 | nikolskoye
# Processing Record 10 of Set 10 | whyalla
# Processing Record 11 of Set 11 | bluff
# Not found. Skipping...
# Processing Record 13 of Set 13 | sandakan
# Processing Record 14 of Set 14 | nome
# Processing Record 15 of Set 15 | yarada
# Processing Record 16 of Set 16 | airai
# Processing Record 17 of Set 17 | tuktoyaktuk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-788233bf598b> in <module>
#      28 for city in cities:
#      29     query_url = f"{url}appid={api_key}&q={city}"
# ---> 30     weather_response = requests.get(query_url)
#      31     weather_json = weather_response.json()
#      32     try:
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = [city, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed]
col_names = ["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]

weather_dict = {
    "City": city_data,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed
}

df = pd.DataFrame(data = weather_dict)
df
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 0                    Rikitea          92      PF  1550540976       100 -23.12
# 1               Punta Arenas          90      CL  1550538000        70 -53.16
# 2                Yellowknife          75      CA  1550538000        76  62.45
# 3                 Bredasdorp          68      ZA  1550538000        83 -34.53
# 4                   Tasiilaq          80      GL  1550537400        57  65.61
# 5                  Busselton           0      AU  1550541044        77 -33.64
# 6                     Hobart          20      AU  1550539440        34 -42.88
# 7                     Waddan           0      LY  1550541113        75  29.16
# 8                 Nikolskoye          90      RU  1550538000        74  59.70
# 9                    Whyalla          40      AU  1550538000        52 -33.04
# 10                     Bluff           0      AU  1550541114        35 -23.58
# 11                  Sandakan          75      MY  1550538000        74   5.84
# 12                      Nome          90      US  1550540100        56  30.04
# 13                    Yarada          20      IN  1550538000        88  17.65
# 14                     Airai          36      TL  1550541004        90  -8.93
# 15               Tuktoyaktuk          90      CA  1550538000        84  69.44
# 16                 Mount Isa           0      AU  1550538000        34 -20.73
# 17                    Namibe          80      AO  1550541118       100 -15.19
# 18                 Mahebourg          40      MU  1550538000        94 -20.41
# 19                   Elmvale          90      CA  1550539800        85  44.58
# 20              Port Lincoln          80      AU  1550540821        89 -34.72
# 21                      Sola          90      NO  1550539200        87  58.89
# 22                  Saldanha          92      PT  1550541038        99  41.42
# 23                   Mataura          92      NZ  1550541120        50 -46.19
# 24                 Sistranda           0      NO  1550537400        80  63.73
# 25                  Damietta           0      EG  1550538000        87  31.42
# 26                   Mangrol           0      IN  1550541121        55  25.33
# 27                 Boa Vista          40      BR  1550538000        51   2.82
# 28                   Kendari          88      ID  1550541086        92  -3.99
# 29                    Marzuq           0      YE  1550541149        87  14.40
# ..                       ...         ...     ...         ...       ...    ...
# 541                   Poanas          40      MX  1550536800        14  25.77
# 542             Vysokogornyy           8      RU  1550541337        53  50.10
# 543  Puerto Baquerizo Moreno          64      EC  1550541337        96  -0.90
# 544                Toamasina          40      MG  1550538000        88 -18.17
# 545                    Yulin           0      CN  1550541338        60  38.30
# 546                    Aswan           0      EG  1550541338       100  24.09
# 547                   Kourou          75      GF  1550538000        74   5.16
# 548                    Jizan          40      SA  1550538000        69  16.89
# 549               Minatitlan           5      MX  1550537160        78  19.39
# 550                 Manicore           8      BR  1550541340        69  -5.81
# 551             Vila do Maio           0      CV  1550541340       100  15.13
# 552                 Denpasar          20      ID  1550538000        79  -8.65
# 553                   Ouango           8      CD  1550541341        64   4.31
# 554          Port Hawkesbury          90      CA  1550539800        78  45.62
# 555                  Karakol           8      KG  1550541341        62  42.49
# 556                   Tokmak           0      UA  1550541342        81  47.26
# 557                   Sangar          48      RU  1550541342        26  63.92
# 558                    Jales           0      BR  1550541145        88 -20.27
# 559             Levokumskoye          76      RU  1550541343        62  44.82
# 560                   Mehamn          36      NO  1550541343        86  71.03
# 561                 Pochutla          90      MX  1550537100        69  15.74
# 562                 Chunskiy          36      RU  1550541343        67  56.08
# 563                  Changli          64      CN  1550541344        94  30.54
# 564                Les Cayes          20      HT  1550541221        97  18.19
# 565                   Kuytun          12      RU  1550541344        69  54.34
# 566              Grand-Santi          20      GF  1550541345        80   4.27
# 567               San Miguel           0      AR  1550538000        69 -34.54
# 568                   Hwange           0      ZW  1550541347        77 -18.35
# 569                    Tigil          76      RU  1550541347        90  57.80
# 570              Henties Bay           8      NA  1550541104       100 -22.12
#
#         Lng  Max Temp  Wind Speed
# 0   -134.97   299.103       12.51
# 1    -70.91   281.150        4.60
# 2   -114.38   250.150        2.10
# 3     20.04   294.150        3.60
# 4    -37.64   268.150       10.80
# 5    115.35   297.803        4.81
# 6    147.33   292.150        9.80
# 7     16.14   272.678        2.41
# 8     30.79   274.150        4.00
# 9    137.58   294.150        6.20
# 10   149.07   309.003        2.06
# 11   118.12   303.150        2.10
# 12   -94.42   287.150        5.70
# 13    83.27   297.150        1.00
# 14   125.41   298.353        0.76
# 15  -133.03   258.150        5.10
# 16   139.49   309.150        7.20
# 17    12.15   295.603        2.81
# 18    57.70   299.150        1.50
# 19   -79.86   261.150        3.10
# 20   135.86   292.228        3.76
# 21     5.65   280.150        7.70
# 22    -6.55   278.203        1.81
# 23   168.86   296.228       10.06
# 24     8.83   277.150        4.10
# 25    31.81   286.150        4.10
# 26    76.51   289.353        1.11
# 27   -60.67   302.150        3.10
# 28   122.52   299.828        1.76
# 29    46.47   280.903        1.21
# ..      ...       ...         ...
# 541 -103.61   301.150        2.10
# 542  139.13   267.453        1.46
# 543  -89.60   300.728        2.46
# 544   49.38   298.150        2.10
# 545  109.75   269.803        2.06
# 546   32.90   278.453        3.46
# 547  -52.64   300.150        4.60
# 548   42.56   299.150        1.50
# 549 -104.05   298.150        4.10
# 550  -61.30   301.428        2.06
# 551  -23.22   293.103        4.91
# 552  115.22   302.150        2.60
# 553   22.55   296.178        2.66
# 554  -61.36   262.150        4.60
# 555   78.39   259.678        0.51
# 556   35.70   264.678        1.31
# 557  127.47   245.203        2.41
# 558  -50.55   294.828        3.86
# 559   44.66   268.928        8.26
# 560   27.85   262.653        3.01
# 561  -96.47   300.150        5.10
# 562   99.63   264.953        1.31
# 563  105.42   280.703        1.96
# 564  -73.75   299.353        5.81
# 565  101.51   261.203        1.61
# 566  -54.38   298.153        1.71
# 567  -58.72   301.150        1.50
# 568   26.50   289.403        4.16
# 569  158.67   261.503        2.06
# 570   14.28   290.178        1.66
#
# [571 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
import datetime
d = datetime.datetime.today()
x = df["Lat"]
y = df["Max Temp"]
plt.scatter(x, y, c = 'lightblue', edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title(f"City Latitude vs. Max Temperature ({d.strftime('%m-%d-%Y')})")
plt.grid(True)
plt.savefig('lat_max_temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = df["Lat"]
y = df["Humidity"]
plt.scatter(x, y, c = 'lightblue', edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({d.strftime('%m-%d-%Y')})")
plt.grid(True)
plt.savefig('lat_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x = df["Lat"]
y = df["Cloudiness"]
plt.scatter(x, y, c = 'lightblue', edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness ({d.strftime('%m-%d-%Y')})")
plt.grid(True)
plt.savefig('lat_cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x = df["Lat"]
y = df["Wind Speed"]
plt.scatter(x, y, c = 'lightblue', edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({d.strftime('%m-%d-%Y')})")
plt.grid(True)
plt.savefig('lat_wind_speed.png')
